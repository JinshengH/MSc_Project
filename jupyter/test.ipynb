# %%
# from datasets import load_dataset

# ds = load_dataset(
#     "sedrickkeh/snli-ve",
#     cache_dir="./datasets"
# )

# ds.save_to_disk("./snli-ve")
# Out:
# ...
# Saving the dataset (5/5 shards): 100%|███████████████████████████████████| 17901/17901 [00:10<00:00, 1739.01 examples/s]

# %%
from datasets import load_from_disk
import pandas as pd

ds = load_from_disk("./snli-ve")
df = ds["train"].select(range(5)).to_pandas()

df
# Out:
#                                                image        filename  \
# 0  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...  4564320256.jpg
# 1  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...  4564320256.jpg
# 2  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...  4564320256.jpg
# 3  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...  4564320256.jpg
# 4  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...  4564320256.jpg
#
#                                              premise  \
# 0  An old lady and her granddaughter working in a...
# 1  An old lady and her granddaughter working in a...
# 2  An old lady and her granddaughter working in a...
# 3  An elderly lady with a young girl are sitting,...
# 4  An elderly lady with a young girl are sitting,...
#
#                                           hypothesis  label
# 0           Two old men robbing a convenience store.      2
# 1                             Two humans in a store.      0
# ...

# %%
ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'filename', 'premise', 'hypothesis', 'label'],
#         num_rows: 529527
#     })
#     validation: Dataset({
#         features: ['image', 'filename', 'premise', 'hypothesis', 'label'],
#         num_rows: 17858
#     })
#     test: Dataset({
#         features: ['image', 'filename', 'premise', 'hypothesis', 'label'],
#         num_rows: 17901
#     })
# })

# %%
sample = ds["train"][0]

print(sample["premise"])
print(sample["hypothesis"])
print(sample["label"])

sample["image"]
# Out:
# An old lady and her granddaughter working in a convenience store.
# Two old men robbing a convenience store.
# 2
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x335>
